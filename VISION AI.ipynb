# %%
# !pip install pyaudio
# Out:
# Collecting pyaudio
#   Downloading PyAudio-0.2.12.tar.gz (42 kB)
#      |████████████████████████████████| 42 kB 247 kB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: pyaudio
#   Building wheel for pyaudio (PEP 517) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/rishupranjal/opt/anaconda3/bin/python /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py build_wheel /var/folders/sl/_dvc7y295vz1kz_zysrpsnf40000gn/T/tmpygh38t1c
#        cwd: /private/var/folders/sl/_dvc7y295vz1kz_zysrpsnf40000gn/T/pip-install-1p3tevbs/pyaudio_c86b30b8beaf4e428b2c8f0e3abb015b
#   Complete output (16 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-cpython-38
#   copying src/pyaudio.py -> build/lib.macosx-10.9-x86_64-cpython-38
#   running build_ext
#   building '_portaudio' extension
#   creating build/temp.macosx-10.9-x86_64-cpython-38
#   creating build/temp.macosx-10.9-x86_64-cpython-38/src
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/Users/rishupranjal/opt/anaconda3/include -arch x86_64 -I/Users/rishupranjal/opt/anaconda3/include -arch x86_64 -DMACOSX=1 -I/usr/local/include -I/usr/include -I/Users/rishupranjal/opt/anaconda3/include/python3.8 -c src/_portaudiomodule.c -o build/temp.macosx-10.9-x86_64-cpython-38/src/_portaudiomodule.o
#   src/_portaudiomodule.c:31:10: fatal error: 'portaudio.h' file not found
#   #include "portaudio.h"
#            ^~~~~~~~~~~~~
#   1 error generated.
#   error: command '/usr/bin/gcc' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for pyaudio
# Failed to build pyaudio
# ERROR: Could not build wheels for pyaudio which use PEP 517 and cannot be installed directly

# %%
# !pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (2.90)
# Requirement already satisfied: pyobjc>=2.4 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Automator==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-OSLog==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AdServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Social==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PushKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Photos==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Contacts==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MailKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PassKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-core==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreData==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Metal==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-EventKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Quartz==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AVKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-GameController==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-GameKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-NetFS==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Accounts==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Network==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreText==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Intents==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Vision==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-WebKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Speech==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Security==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MapKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreML==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CallKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc>=2.4->pyttsx3) (8.5.1)

# %%
# !pip install pywhatkit
# Out:
# Collecting pywhatkit
#   Using cached pywhatkit-5.4-py3-none-any.whl (15 kB)
# Requirement already satisfied: requests in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pywhatkit) (2.25.1)
# Requirement already satisfied: Flask in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pywhatkit) (1.1.2)
# Collecting wikipedia
#   Using cached wikipedia-1.4.0-py3-none-any.whl
# Collecting pyautogui
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7fbe1c4388e0>, 'Connection to files.pythonhosted.org timed out. (connect timeout=15)')': /packages/f0/76/7a0ec1013bc3559b7438f6773cba05ffaec600b8989be2d621a144e39b50/PyAutoGUI-0.9.53.tar.gz
#   Downloading PyAutoGUI-0.9.53.tar.gz (59 kB)
#      |████████████████████████████████| 59 kB 218 kB/s eta 0:00:01
# Requirement already satisfied: Pillow in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pywhatkit) (8.2.0)
# Requirement already satisfied: itsdangerous>=0.24 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from Flask->pywhatkit) (1.1.0)
# Requirement already satisfied: Werkzeug>=0.15 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from Flask->pywhatkit) (1.0.1)
# Requirement already satisfied: click>=5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from Flask->pywhatkit) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from Flask->pywhatkit) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from Jinja2>=2.10.1->Flask->pywhatkit) (1.1.1)
# Collecting pymsgbox
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting PyTweening>=1.0.1
#   Downloading pytweening-1.0.4.tar.gz (14 kB)
# Collecting pyscreeze>=0.1.21
#   Downloading PyScreeze-0.1.28.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting pygetwindow>=0.0.5
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
# Collecting mouseinfo
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
# Requirement already satisfied: pyobjc-core in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyautogui->pywhatkit) (8.5.1)
# Collecting pyrect
#   Downloading PyRect-0.2.0.tar.gz (17 kB)
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Collecting rubicon-objc
#   Downloading rubicon_objc-0.4.2-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 227 kB/s eta 0:00:01
# Requirement already satisfied: pyobjc-framework-CoreData==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Security==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Intents==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AVKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-EventKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-IMServicePlugIn==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreText==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PassKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Speech==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Vision==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Metal==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MapKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Network==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-GameController==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MailKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-WebKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Quartz==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CallKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-GameKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Automator==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreML==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-NetFS==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Photos==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AdServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-PushKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Accounts==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Contacts==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-OSLog==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-Social==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==8.5.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from pyobjc->pyautogui->pywhatkit) (8.5.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from requests->pywhatkit) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from requests->pywhatkit) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from requests->pywhatkit) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from requests->pywhatkit) (2020.12.5)
# Requirement already satisfied: beautifulsoup4 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from wikipedia->pywhatkit) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/rishupranjal/opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->wikipedia->pywhatkit) (2.2.1)
# Building wheels for collected packages: pyautogui, pygetwindow, pyscreeze, PyTweening, mouseinfo, pymsgbox, pyperclip, pyrect
#   Building wheel for pyautogui (setup.py) ... done
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36583 sha256=f17f6d50a07960df6b28c50728f9837764ddd4986972947d937cd5d1d63cb219
#   Stored in directory: /Users/rishupranjal/Library/Caches/pip/wheels/54/04/f7/55704a9d374ed923785a4fdc0ef00151fa25306b3b93345532
#   Building wheel for pygetwindow (setup.py) ... done
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11078 sha256=35b6ab488e5b030543b0cd224aa331d425970138707af90099161c217f19667e
#   Stored in directory: /Users/rishupranjal/Library/Caches/pip/wheels/91/e3/04/184bda98ec7f7d5f0ba1f372bcf7b3ba86325151ae1dd690fe
#   Building wheel for pyscreeze (PEP 517) ... done
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.28-py3-none-any.whl size=13009 sha256=cafcc8d4cc4483b190fb87b5b4b873ae4da9c155046cd8004dfbc37657e922d2
#   Stored in directory: /Users/rishupranjal/Library/Caches/pip/wheels/b1/b0/5c/9fb5beb2d6c708479a670e92f4ab3b54523a15c9cd4a46e24e
#   Building wheel for PyTweening (setup.py) ... done
#   Created wheel for PyTweening: filename=pytweening-1.0.4-py3-none-any.whl size=5825 sha256=e396b82a032dbf8dee07f4cab31fee125881e606ec06427af8b34acec6165a3e
#   Stored in directory: /Users/rishupranjal/Library/Caches/pip/wheels/a2/1b/69/dc477653ccc19228bf53af76c623e4e82e5dc1b6f78d5c4d35
#   Building wheel for mouseinfo (setup.py) ... done
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10905 sha256=3c983a1bd18baa396738e7bfbde38b16200b675a11216543ef2faf59041a0860
#   Stored in directory: /Users/rishupranjal/Library/Caches/pip/wheels/d1/72/fb/35f403de66285df8ecca7049bcc61bfb57aba0f76d1f08f7eb
#   Building wheel for pymsgbox (PEP 517) ... done
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7406 sha256=8185a2c4b35fdd4d172f94dfd56afbfa074f74cb036f90453fcd3664b6f0ce93
#   Stored in directory: /Users/rishupranjal/Library/Caches/pip/wheels/91/28/0d/f4eb606d38276836237d6dc2abf094241e6db5682a126e0389
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11107 sha256=5f4f65568ea2aeb73105edbb3f889680722bc0bf9209d35f09cf1adb74b2ea2b
#   Stored in directory: /Users/rishupranjal/Library/Caches/pip/wheels/7f/1a/65/84ff8c386bec21fca6d220ea1f5498a0367883a78dd5ba6122
#   Building wheel for pyrect (setup.py) ... done
#   Created wheel for pyrect: filename=PyRect-0.2.0-py2.py3-none-any.whl size=11167 sha256=164c8c2f7dbd45bf26a1e19165fedefc7295290ed25816c31e8dc0ffb68c81ee
#   Stored in directory: /Users/rishupranjal/Library/Caches/pip/wheels/1b/c1/cc/3d6515746ab138a303b6b5d38181399703488f8109b734e768
# Successfully built pyautogui pygetwindow pyscreeze PyTweening mouseinfo pymsgbox pyperclip pyrect
# Installing collected packages: rubicon-objc, pyrect, pyperclip, PyTweening, pyscreeze, pymsgbox, pygetwindow, mouseinfo, wikipedia, pyautogui, pywhatkit
# Successfully installed PyTweening-1.0.4 mouseinfo-0.1.3 pyautogui-0.9.53 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.2.0 pyscreeze-0.1.28 pywhatkit-5.4 rubicon-objc-0.4.2 wikipedia-1.4.0

# %%
# !pip install pyjokes
# Out:
# Collecting pyjokes
#   Downloading pyjokes-0.6.0-py2.py3-none-any.whl (26 kB)
# Installing collected packages: pyjokes
# Successfully installed pyjokes-0.6.0

# %%
import speech_recognition as sr
import pyttsx3
import pywhatkit
import datetime
import wikipedia
import pyjokes
import sys
import webbrowser
from datetime import date

engine=pyttsx3.init()
engine.setProperty("rate",150)
voices = engine.getProperty("voices")
engine.setProperty('voice',voices[0].id)
recognizer=sr.Recognizer()

def engine_talk(text):
  engine.say(text)
  engine.runAndWait()

def VISION():

  with sr.Microphone() as source:
     recognizer.ajust_for_ambient_noise(source,duration=1)
      print('\n')
      print("Start Speaking!!")
      engine_talk('listening.. ')
      recordedaudio=recognizer.listen(source)
  try :
     command=recognizer.recognize_google(recordedaudio,language='en-in')
     command = command.lower()
     if 'VISION' in command:
        comamnd = command.replce('VISION', '')
        print('you said'+command)
     else:
       print('you said :'+command)
     if 'hello' in command :
       print('hello how can i help you ??')         
       engine_talk('hello, how can i help you ??')
     elif 'who are you' in command :
       print('I am VISION a k a your virtual assistant master')
       engine_talk('I am VISION a k a your virtual assistant master. how can i help you ??')

     elif 'can you do' in command:
         print('''i can play songs on youtube , tell you a joke, search on wikipedia, tell date and time,find your location, locate area on map,
                open different websites like instagram, youtube,gmail,git hub, stack overflow and searches on google. How may i help you ??''')
         engine_talk('''i can play songs on youtube , tell you a joke, search on wikipedia, tell date and time,find your location, locate area on map,
                     open different websites like instagram, youtube,gmail,git hub, stack overflow and searches on google. How may i help you ??''')
         
     elif 'play' in command:
         song= command.replace('play', '')
         print('Playing'+song)
         engine_talk('Playing' +song)
         pywhatkit.playonyt(song)

     elif 'date and time' in command:
         today = date.today()
         time = datetime.datetime.now().steftime('%I :%M %p')
          # Textual month,day and year
         d2 = today.strftime("%B %d, %Y")
         print("Today's Date is ",d2, 'Current time is', time)
         engine_talk('Today is :'+ d2)
         engine_talk('and current time is '+ time)

     elif 'time and date' in command :
          today = date.today()   
          time = datetime.datetime.now() .strftime('%I:%M %p')
          # Textual month,day and year
          d2 = today.strftime("%B %d, %Y")
          print("Today's Date is ", d2, 'Current time is ', time)
          engine_talk('Current time is '+ d2)
          engine_talk('and Today is :'+ d2)

     elif 'time' in command:
          time = datetime.datetime.now().strftime('%I:%M %p')
          print('The current time is ' +time)
          engine_talk('The current time is')
          engine_talk(time)

     elif 'date' in command:
           today = date.today()
           print("Today's date:", today)
           # Textual month,day and year
           d2 = today.strftime ('%B %d, %Y')
           print("Today's Date is ",d2)
           engine_talk('Todays Date is')
           engine_talk(d2)

     
     elif 'tell me about' in command:
          name = command.replace('tell me about', '')
          info = wikipedia.summary(name, 1)
          print(info)
          engine_talk(info)

     elif 'wikipedia' in command:
           name = command.replace('wikipedia', '')
           info = wikipedia.summary(name, 1)
           print(info)
           engine_talk(d2) 

     elif 'what is ' in command :
          name = command.replace('what is ', '')
          info = wikipedia.summary(name, 1)
          print(info)
          engine_talk(info)

     elif 'who is ' in command :
          name = command.replace('who is ', '')
          info = wikipedia.summary(name, 1)
          print(info)
          engine_talk(info)    

     elif 'what is ' in command :
          search = 'https://www.google.com/search?q='+command
          print(' Here is what i found on the internet...')
          engine_talk('searching... Here is what i found on the internet..')
          webbrowser.open(search)
     elif 'joke' in command :
        _joke = pyjokes.get_joke()
        print(_joke)
        engine_talk(_joke)

     elif 'search' in command :
        search = 'https://www.google.com/search?q='+command
        engine_talk('searching...')
        webbrowser.open(search)

     elif "my location" in command:
        url = "https://www.google.com/maps/search/Where+am+I+?/"
        webbrowser.get().open(url)
        engine_talk("You must be somewhere near here, as per Google maps")

     elif 'locate ' in command :
        engine_talk('locating ...')
        loc = command.replace('locate', '')
        if 'on map' in loc:
            loc=loc.replace('on map', ' ')
        url = 'https://www.google.nl/maps/place/'+loc+'/&amp;'
        webbrowser.get().open(url)
        print('Here is the location of '+loc)
        engine_talk('Here is the location of '+loc)

     elif 'on map' in command :
          engine_talk('locating ...')
          loc = command.split(" ")
          print(loc[1])
          url = 'https://google.nl/maps/place/'+loc[1] +'/&amp;'
          webbrowser.get() .open(url)
          print('Her is the location of'+loc[1])
          engine_talk('Here os the location of '+loc[1])

     elif 'location of' in command :
        engine_talk('locating ...')
        loc = command.replace('find location of ', '')
        url = 'https://gooogle.nl/maps/place/'+loc+'/&amp'
        webbrowser.get().open(url)
        print('Here is the location of '+loc)
        engine_talk('Here is the location of '+loc)

     elif 'where is ' in command :
        engine_talk('locating ...')
        loc = command.replace('where is', '')
        url = 'https://gooogle.nl/maps/place/'+loc+'/&amp'
        webbrowser.get().open(url)
        print('Here is the location of '+loc)
        engine_talk('Here is the location of '+loc)

     elif 'open google' in command:
          print('opening google ...')
          engine_talk('opening google..')
          webbrowser.open_new('https://www.google.co.in/')

     elif 'gmail' in command:
          print('opening gmail ...')
          engine_talk('opening gmail..')
          webbrowser.open_new('https://mail.google.com/')

     elif 'open youtube' in command:
          print('opening you tube ...')
          engine_talk('opening you tube..')
          webbrowser.open_new('https://www.//youtube.com/')

     elif 'open instagram' in command:
          print('opening instagram ...')
          engine_talk('opening insta gram..')
          webbrowser.open_new('https://www.instagram.com/')

     elif 'open stack overflow' in command:
          print('opening stackoverflow ...')
          engine_talk('opening stack overflow..')
          webbrowser.open_new('https://www.stackoverflow.com/')    

     elif 'open github' in command:
          print('opening git hub ...')
          engine_talk('opening git hub..')
          webbrowser.open_new('https://www.github.com/')     

     elif 'bye' in command:
          print('good bye,have a nice day !!')
          engine_talk('good bye,have a nice day !!')
          sys.exit()

     elif 'thank you' in command :
          print("your welcome")
          engine_talk('your welcome')

     elif 'stop' in comamnd:
            print('good bye, have a nice day !!') 
            engine_talk('good bye, have a nice day !!') 
            sys.exit()

     elif 'bye' in comamnd:
            print('good bye, have a nice day !!') 
            engine_talk('good bye, have a nice day !!') 
            sys.exit()

     else:
          print(' Here is what i found on the internet..')
          engine_talk(' Here is what i found on the internet..') 
          search = 'https://www.google.com/search?q='+command 
          webbrowser.open(search)

  except Exception as ex:
          print(ex)

print('Clearing background noise...Please wait')
engine_talk('Clearing background noise...Please wait')
print('\n')
print("hello, i am VISION how can i help you ??")
engine_talk ("hello, i am VISION how can i help you ??")


while True:
     VISION()
# Out:
# Clearing background noise...Please wait
#
#
# hello, i am VISION how can i help you ??
#
#
# Start Speaking!!
#
#
#
# Start Speaking!!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-eada90b03f0a> in <module>
#     253
#     254 while True:
# --> 255      VISION()
#
# <ipython-input-2-eada90b03f0a> in VISION()
#      28       recordedaudio=recognizer.listen(source)
#      29   try :
# ---> 30      command=recognizer.recognize_google(recordedaudio,language='en-in')
#      31      command = command.lower()
#      32      if 'VISION' in command:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/speech_recognition/__init__.py in recognize_google(self, audio_data, key, language, show_all)
#     838         # obtain audio transcription results
#     839         try:
# --> 840             response = urlopen(request, timeout=self.operation_timeout)
#     841         except HTTPError as e:
#     842             raise RequestError("recognition request failed: {}".format(e.reason))
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     523
#     524         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _open(self, req, data)
#     540
#     541         protocol = req.type
# --> 542         result = self._call_chain(self.handle_open, protocol, protocol +
#     543                                   '_open', req)
#     544         if result:
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in http_open(self, req)
#    1381
#    1382     def http_open(self, req):
# -> 1383         return self.do_open(http.client.HTTPConnection, req)
#    1384
#    1385     http_request = AbstractHTTPHandler.do_request_
#
# ~/opt/anaconda3/lib/python3.8/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1356             except OSError as err: # timeout error
#    1357                 raise URLError(err)
# -> 1358             r = h.getresponse()
#    1359         except:
#    1360             h.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/opt/anaconda3/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
from google.colab import drive
drive.mount('/content/drive')
